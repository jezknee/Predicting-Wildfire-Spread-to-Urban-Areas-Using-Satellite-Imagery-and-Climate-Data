# %%
# Inputs: Fire Occurrences, Urban Areas 

# Outputs: Shapefile of all wildfires

# Purpose:Get wildfires that started outside urban areas

# %%
import pandas as pd 
import geopandas
import matplotlib.pyplot as plt

# %%
burn_df = geopandas.read_file(r"C:\Users\jezkn\Local\Data Science Projects\MSc Project Data\Data\Burn Area Boundary\S_USA.MTBS_BURN_AREA_BOUNDARY.shp")
burn_df.plot()
plt.show()
# Out:
# C:\Users\jezkn\Anaconda3\lib\site-packages\geopandas\plotting.py:51: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   if geom is not None and geom.type.startswith(prefix) and not geom.is_empty:

# %%
burn_df.head()
# Out:
#                  FIRE_ID FIRE_NAME  YEAR  STARTMONTH  STARTDAY FIRE_TYPE  \
# 0  CA3601111879719850712  TULARE 4  1985           7        12  Wildfire
# 1  WA4820811967519850623     MONSE  1985           6        23  Wildfire
# 2  WA4799411870619850704  KELLERFE  1985           7         4  Wildfire
# 3  WA4845711860619850830   AIRPORT  1985           8        30  Wildfire
# 4  OR4479412120619850615   DUMP 21  1985           6        15  Wildfire
#
#     ACRES IRWINID  MAP_ID MAP_PROG  ... GREENNESS_  LOW_THRESH MODERATE_T  \
# 0  1290.0    None    4752     MTBS  ...       -150          90        233
# 1  2890.0    None    4753     MTBS  ...       -150         200        374
# 2  1695.0    None    4754     MTBS  ...       -150         120        231
# 3  1333.0    None    4755     MTBS  ...       -150         150        350
# 4  2330.0    None    4756     MTBS  ...       -150         100        200
#
#   HIGH_THRES COMMENTS  LATITUDE  LONGITUDE  SHAPE_AREA  SHAPE_LEN  \
# 0        425     None    36.011   -118.797    0.000522   0.129679
# 1        610     None    48.208   -119.675    0.001415   0.183820
# 2        400     None    47.994   -118.706    0.000827   0.133374
# 3        600     None    48.457   -118.606    0.000656   0.139803
# 4       9999     None    44.794   -121.206    0.001072   0.257790
#
#                                             geometry
# 0  POLYGON ((-118.78172 35.99641, -118.78252 35.9...
# 1  POLYGON ((-119.65653 48.18909, -119.65801 48.1...
# 2  POLYGON ((-118.70041 47.97118, -118.70043 47.9...
# 3  POLYGON ((-118.58630 48.46931, -118.58504 48.4...
# 4  POLYGON ((-121.21845 44.77088, -121.21909 44.7...
#
# [5 rows x 28 columns]

# %%
occurrences_df = geopandas.read_file(r"C:\Users\jezkn\Local\Data Science Projects\MSc Project Data\Data\Fire Occurrences\S_USA.MTBS_FIRE_OCCURRENCE_PT.shp")
occurrences_df.plot()
plt.show()

# %%
occurrences_df["IG_DATE"] = occurrences_df["IG_DATE"] = pd.to_datetime(occurrences_df["IG_DATE"])
occurrences_df.head()
# Out:
#                  FIRE_ID  FIRE_NAME ASMNT_TYPE FIRE_TYPE  NODATA_THR  \
# 0  OK3659009620620240405    STABLER    Initial  Wildfire      -970.0
# 1  CA4137212367320230815   MOSQUITO   Extended  Wildfire      -970.0
# 2  NV4190111855220240707     WILDER    Initial  Wildfire      -970.0
# 3  OK3633309639020240320  BIG CEDAR    Initial  Wildfire      -970.0
# 4  CA4185912384020230815      KELLY   Extended  Wildfire      -970.0
#
#    GREENNESS_  LOW_THRESH  MODERATE_T  HIGH_THRES    IG_DATE  ...  \
# 0      -150.0       -37.0      9999.0      9999.0 2024-04-05  ...
# 1      -150.0        60.0       317.0       600.0 2023-08-15  ...
# 2      -150.0        55.0      9999.0      9999.0 2024-07-07  ...
# 3      -150.0        36.0      9999.0      9999.0 2024-03-20  ...
# 4      -150.0        40.0       309.0       600.0 2023-08-15  ...
#
#                                 IRWINID    MAP_ID  MAP_PROG PERIM_ID  \
# 0  1BD6573A-3DA5-4B3E-ADA4-0B8AD652D3CD  10030509      MTBS     None
# 1  C6CFF715-78DB-4D64-A750-9DB12A048A36  10030513      MTBS     None
# 2  5CFBDE78-52B3-4A38-BFEE-5D42F2369A6D  10030514      MTBS     None
# 3  9333FA57-DCCB-449C-A391-3E57439BDFC0  10030515      MTBS     None
# 4  531B9F1B-1B36-4B91-8E63-2AADA4881DEB  10030523      MTBS     None
#
#    DNBR_OFFST DNBR_STDDV                                           COMMENTS  \
# 0         -59         20                                               None
# 1           4         26  CA4155412365920230828, CA4152312372120230815, ...
# 2          -8          5                                               None
# 3         -13         29                                               None
# 4           8         17  CA4178812391520230815, CA4185912383420230816, ...
#
#                PRE_ID             POST_ID                     geometry
# 0  A14SQF20240403_30m  A14SQF20240413_30m   POINT (-96.21395 36.58433)
# 1     804603120230715     804603120240717  POINT (-123.66698 41.47588)
# 2     904303120240704     804303120240712  POINT (-118.51891 41.84468)
# 3  B14SQF20240309_30m  A14SQF20240403_30m   POINT (-96.39208 36.33635)
# 4     804603120230715     804603120240717  POINT (-123.85209 41.90792)
#
# [5 rows x 23 columns]

# %%
urban_df = geopandas.read_file(r"C:\Users\jezkn\Local\Data Science Projects\MSc Project Data\Data\WUI\Urban Areas\tl_2020_us_uac20.shp")
urban_df.plot()
plt.show()
# Out:
# C:\Users\jezkn\Anaconda3\lib\site-packages\geopandas\plotting.py:51: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   if geom is not None and geom.type.startswith(prefix) and not geom.is_empty:

# %%
urban_2000 = geopandas.read_file(r"C:\Users\jezkn\Local\Data Science Projects\MSc Project Data\Data\WUI\Urban Areas\tl_2008_us_uac00.shp")
urban_2000.head()
# Out:
#   UACE00          NAME00                    NAMELSAD00 LSAD00 MTFCC00  \
# 0  21016     Creston, IA     Creston, IA Urban Cluster     76   G3500
# 1  32626     Garnett, KS     Garnett, KS Urban Cluster     76   G3500
# 2  47881      Larned, KS      Larned, KS Urban Cluster     76   G3500
# 3  78283      Salina, KS      Salina, KS Urban Cluster     76   G3500
# 4  32032  Fulton, KY--TN  Fulton, KY--TN Urban Cluster     76   G3500
#
#   FUNCSTAT00                                           geometry
# 0          S  POLYGON ((-94.38236 41.04811, -94.38047 41.049...
# 1          S  POLYGON ((-95.25182 38.28833, -95.25151 38.288...
# 2          S  MULTIPOLYGON (((-99.13748 38.17818, -99.13678 ...
# 3          S  MULTIPOLYGON (((-97.64526 38.83928, -97.64489 ...
# 4          S  MULTIPOLYGON (((-88.92482 36.48990, -88.92481 ...

# %%
urban_2010 = geopandas.read_file(r"C:\Users\jezkn\Local\Data Science Projects\MSc Project Data\Data\WUI\Urban Areas\tl_2010_us_uac10.shp")
urban_2010.head()
# Out:
#   UACE10 GEOID10                         NAME10  \
# 0  13550   13550               Captain Cook, HI
# 1  36231   36231  Haleiwa--Waialua--Pupukea, HI
# 2  37716   37716     Hawaiian Paradise Park, HI
# 3  39052   39052                       Hilo, HI
# 4  39862   39862                    Honokaa, HI
#
#                                     NAMELSAD10 LSAD10 MTFCC10 UATYP10  \
# 0               Captain Cook, HI Urban Cluster     76   G3500       C
# 1  Haleiwa--Waialua--Pupukea, HI Urban Cluster     76   G3500       C
# 2     Hawaiian Paradise Park, HI Urban Cluster     76   G3500       C
# 3                       Hilo, HI Urban Cluster     76   G3500       C
# 4                    Honokaa, HI Urban Cluster     76   G3500       C
#
#   FUNCSTAT10   ALAND10  AWATER10   INTPTLAT10    INTPTLON10  \
# 0          S  10828493         0  +19.4851399  -155.9048039
# 1          S  14575290    199739  +21.5700076  -158.1267583
# 2          S  83608315         0  +19.5520074  -154.9575896
# 3          S  63522148    182714  +19.7036027  -155.0878720
# 4          S   4066412         0  +20.0757697  -155.4604060
#
#                                             geometry
# 0  MULTIPOLYGON (((-155.92016 19.50094, -155.9202...
# 1  POLYGON ((-158.07298 21.62986, -158.07294 21.6...
# 2  MULTIPOLYGON (((-154.94861 19.49653, -154.9486...
# 3  MULTIPOLYGON (((-155.13467 19.68449, -155.1345...
# 4  MULTIPOLYGON (((-155.47943 20.08121, -155.4794...

# %%
urban_2020 = geopandas.read_file(r"C:\Users\jezkn\Local\Data Science Projects\MSc Project Data\Data\WUI\Urban Areas\tl_2020_us_uac20.shp")
urban_2020.head()
# Out:
#   UACE20 GEOID20        NAME20               NAMELSAD20 LSAD20 MTFCC20  \
# 0  67240   67240     Pampa, TX     Pampa, TX Urban Area     67   G3500
# 1  23230   23230     Delta, CO     Delta, CO Urban Area     67   G3500
# 2  36001   36001  Gunnison, CO  Gunnison, CO Urban Area     67   G3500
# 3  45775   45775      Kuna, ID      Kuna, ID Urban Area     67   G3500
# 4  05410   05410    Basalt, CO    Basalt, CO Urban Area     67   G3500
#
#   UATYP20 FUNCSTAT20   ALAND20  AWATER20   INTPTLAT20    INTPTLON20  \
# 0       U          S  21374659         0  +35.5451610  -100.9656498
# 1       U          S  16126572    129608  +38.7454236  -108.0619343
# 2       U          S   9468678     11725  +38.5405505  -106.9384998
# 3       U          S  16384896     46009  +43.5010643  -116.4168990
# 4       U          S   9433311     68797  +39.3835983  -107.0807354
#
#                                             geometry
# 0  POLYGON ((-100.94529 35.53833, -100.94525 35.5...
# 1  POLYGON ((-108.04131 38.74094, -108.04100 38.7...
# 2  POLYGON ((-106.92674 38.53565, -106.92795 38.5...
# 3  MULTIPOLYGON (((-116.39896 43.48833, -116.3988...
# 4  MULTIPOLYGON (((-107.11050 39.40463, -107.1104...

# %%
burn_2020 = burn_df[burn_df["YEAR"] > 2019]
burn_2010 = burn_df[(burn_df["YEAR"] > 2009) & (burn_df["YEAR"] <= 2019)]
burn_2000 = burn_df[burn_df["YEAR"] <= 2010]

# %%
urban_fire_df_2020 = geopandas.sjoin(burn_2020, urban_2020, op='intersects')
urban_fire_df_2010 = geopandas.sjoin(burn_2010, urban_2010, op='intersects')
urban_fire_df_2000 = geopandas.sjoin(burn_2000, urban_2000, op='intersects')
# Out:
# C:\Users\jezkn\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3248: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\jezkn\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3248: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\jezkn\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3248: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
occ_2020 = occurrences_df[occurrences_df["IG_DATE"] > "2019-12-31"]
occ_2010 = occurrences_df[(occurrences_df["IG_DATE"] > "2009-12-31") & (occurrences_df["IG_DATE"] <= "2019-12-31")]
occ_2000 = occurrences_df[occurrences_df["IG_DATE"] <= "2009-12-31"]

# %%
occ_df_2020 = geopandas.sjoin(occ_2020, urban_2020, op='intersects')
occ_df_2010 = geopandas.sjoin(occ_2010, urban_2010, op='intersects')
occ_df_2000 = geopandas.sjoin(occ_2000, urban_2000, op='intersects')
# Out:
# C:\Users\jezkn\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3248: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\jezkn\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3248: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\jezkn\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3248: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
urban_fire_df = pd.concat([urban_fire_df_2020, urban_fire_df_2010, urban_fire_df_2000])
urban_fire_df['CrossedWUI'] = 1
len(urban_fire_df)
# Out:
# 731

# %%
occ_fire_df = pd.concat([occ_df_2020, occ_df_2010, occ_df_2000])
occ_fire_df['UrbanOccurrence'] = 1
len(occ_fire_df)
# Out:
# 85

# %%
urban_fire_lookup = urban_fire_df[['FIRE_ID','MAP_ID', 'CrossedWUI']]
occ_fire_lookup = occ_fire_df[['FIRE_ID','MAP_ID', 'UrbanOccurrence']]
urban_fire_lookup.head()
# Out:
#                      FIRE_ID    MAP_ID  CrossedWUI
# 17181  FL3040908437220220111  10024774           1
# 17221  FL3038108433520220129  10024796           1
# 18333  FL3036508438420210305  10022103           1
# 17233  FL2576508042220220329  10024307           1
# 17612  FL3017908559620220304  10025112           1

# %%
urban_fire_lookup = urban_fire_lookup.drop_duplicates()
occ_fire_lookup = occ_fire_lookup.drop_duplicates()
urban_fire_lookup.head(1000)
# Out:
#                      FIRE_ID    MAP_ID  CrossedWUI
# 17181  FL3040908437220220111  10024774           1
# 17221  FL3038108433520220129  10024796           1
# 18333  FL3036508438420210305  10022103           1
# 17233  FL2576508042220220329  10024307           1
# 17612  FL3017908559620220304  10025112           1
# ...                      ...       ...         ...
# 16439  SC3297007995320080129     17297           1
# 16477  MI4464108471520080424     17198           1
# 16919  VA3736807999720080210  10003638           1
# 16936  TX3524510186220080315     17526           1
# 28383  AK6480214761620100424     18607           1
#
# [677 rows x 3 columns]

# %%
occ2 = pd.merge(urban_fire_lookup, occ_fire_lookup, on = ['FIRE_ID', 'MAP_ID'], how='left')
occ2['CrossedWUI'].fillna(0, inplace=True)
occ2['UrbanOccurrence'].fillna(0, inplace=True)
occ2.head()
# Out:
#                  FIRE_ID    MAP_ID  CrossedWUI  UrbanOccurrence
# 0  FL3040908437220220111  10024774           1              0.0
# 1  FL3038108433520220129  10024796           1              0.0
# 2  FL3036508438420210305  10022103           1              0.0
# 3  FL2576508042220220329  10024307           1              0.0
# 4  FL3017908559620220304  10025112           1              0.0

# %%
occ2 = pd.merge(occurrences_df, occ2, on = ['FIRE_ID', 'MAP_ID'], how='left')
occ2['CrossedWUI'].fillna(0, inplace=True)
occ2['UrbanOccurrence'].fillna(0, inplace=True)
occ2.head()
# Out:
#                  FIRE_ID  FIRE_NAME ASMNT_TYPE FIRE_TYPE  NODATA_THR  \
# 0  OK3659009620620240405    STABLER    Initial  Wildfire      -970.0
# 1  CA4137212367320230815   MOSQUITO   Extended  Wildfire      -970.0
# 2  NV4190111855220240707     WILDER    Initial  Wildfire      -970.0
# 3  OK3633309639020240320  BIG CEDAR    Initial  Wildfire      -970.0
# 4  CA4185912384020230815      KELLY   Extended  Wildfire      -970.0
#
#    GREENNESS_  LOW_THRESH  MODERATE_T  HIGH_THRES    IG_DATE  ...  MAP_PROG  \
# 0      -150.0       -37.0      9999.0      9999.0 2024-04-05  ...      MTBS
# 1      -150.0        60.0       317.0       600.0 2023-08-15  ...      MTBS
# 2      -150.0        55.0      9999.0      9999.0 2024-07-07  ...      MTBS
# 3      -150.0        36.0      9999.0      9999.0 2024-03-20  ...      MTBS
# 4      -150.0        40.0       309.0       600.0 2023-08-15  ...      MTBS
#
#    PERIM_ID  DNBR_OFFST DNBR_STDDV  \
# 0      None         -59         20
# 1      None           4         26
# 2      None          -8          5
# 3      None         -13         29
# 4      None           8         17
#
#                                             COMMENTS              PRE_ID  \
# 0                                               None  A14SQF20240403_30m
# 1  CA4155412365920230828, CA4152312372120230815, ...     804603120230715
# 2                                               None     904303120240704
# 3                                               None  B14SQF20240309_30m
# 4  CA4178812391520230815, CA4185912383420230816, ...     804603120230715
#
#               POST_ID                     geometry  CrossedWUI UrbanOccurrence
# 0  A14SQF20240413_30m   POINT (-96.21395 36.58433)         0.0             0.0
# 1     804603120240717  POINT (-123.66698 41.47588)         0.0             0.0
# 2     804303120240712  POINT (-118.51891 41.84468)         0.0             0.0
# 3  A14SQF20240403_30m   POINT (-96.39208 36.33635)         0.0             0.0
# 4     804603120240717  POINT (-123.85209 41.90792)         0.0             0.0
#
# [5 rows x 25 columns]

# %%
occ2.columns.tolist()
# Out:
# ['FIRE_ID',
#  'FIRE_NAME',
#  'ASMNT_TYPE',
#  'FIRE_TYPE',
#  'NODATA_THR',
#  'GREENNESS_',
#  'LOW_THRESH',
#  'MODERATE_T',
#  'HIGH_THRES',
#  'IG_DATE',
#  'LATITUDE',
#  'LONGITUDE',
#  'ACRES',
#  'IRWINID',
#  'MAP_ID',
#  'MAP_PROG',
#  'PERIM_ID',
#  'DNBR_OFFST',
#  'DNBR_STDDV',
#  'COMMENTS',
#  'PRE_ID',
#  'POST_ID',
#  'geometry',
#  'CrossedWUI',
#  'UrbanOccurrence']

# %%
occ4 = occ2[['FIRE_ID','FIRE_NAME','FIRE_TYPE','IG_DATE','LATITUDE','LONGITUDE','geometry','CrossedWUI','UrbanOccurrence']]
occ4 = occ4[occ4['UrbanOccurrence'] == 0]
occ4['IG_DATE'] = occ4['IG_DATE'].astype(str)
len(occ4)

# %%
occ3 = occ4[occ4['UrbanOccurrence'] == 1]
occ3.head()
# Out:
# Empty GeoDataFrame
# Columns: [FIRE_ID, FIRE_NAME, FIRE_TYPE, IG_DATE, LATITUDE, LONGITUDE, geometry, CrossedWUI, UrbanOccurrence]
# Index: []

# %%
occ4.to_file(r"C:\Users\jezkn\OneDrive\Documents\Birkbeck\Work\MSc Project\Wildfire Project\Outputs\FINAL_PartOneOutput.shp")
# Out:
# C:\Users\jezkn\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   """Entry point for launching an IPython kernel.

# %%
occ6 = occ4[['FIRE_ID','CrossedWUI']]
occ6.groupby(['CrossedWUI']).size()
# Out:
# CrossedWUI
# 0.0    30053
# 1.0      592
# dtype: int64
